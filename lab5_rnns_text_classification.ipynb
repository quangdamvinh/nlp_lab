# %%
import numpy as np
import pandas as pd
from gensim.models import Word2Vec

from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM

# %%
train = pd.read_csv('datasets/hwu/train.csv')
val = pd.read_csv('datasets/hwu/val.csv')

# %%
print("Train shape:", train.shape)
print("Validation shape:", val.shape)
train.head()
# Out:
# Train shape: (8954, 2)
# Validation shape: (1076, 2)
#                                                 text     category
# 0                what alarms do i have set right now  alarm_query
# 1                    checkout today alarm of meeting  alarm_query
# 2                              report alarm settings  alarm_query
# 3  see see for me the alarms that you have set to...  alarm_query
# 4                       is there an alarm for ten am  alarm_query

# %%
le = LabelEncoder()
train_labels = le.fit_transform(train['category'])
val_labels = le.transform(val['category'])
num_classes = len(set(train_labels))
num_classes
# Out:
# 64

# %% [markdown]
# ### TF-IDF + Logistic Regression

# %%
tfidf_lr_pipeline = make_pipeline(
    TfidfVectorizer(max_features=5000),
    LogisticRegression(max_iter=1000)
)

# %%
tfidf_lr_pipeline.fit(train['text'], train_labels)
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer(max_features=5000)),
#                 ('logisticregression', LogisticRegression(max_iter=1000))])

# %%
y_pred = tfidf_lr_pipeline.predict(val['text'])
print(classification_report(val_labels, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.95      0.86        19
#            1       0.75      0.55      0.63        11
#            2       0.74      0.74      0.74        19
#            3       0.62      0.62      0.62         8
#            4       1.00      0.53      0.70        15
#            5       0.79      0.85      0.81        13
#            6       0.77      0.53      0.62        19
#            7       0.82      0.95      0.88        19
#            8       0.88      0.79      0.83        19
#            9       0.94      0.89      0.92        19
#           10       0.56      0.62      0.59         8
#           11       0.82      0.74      0.78        19
#           12       1.00      0.88      0.93         8
#           13       0.94      0.89      0.92        19
#           14       0.94      0.84      0.89        19
#           15       0.90      0.95      0.92        19
#           16       1.00      0.89      0.94        19
#           17       0.90      0.95      0.92        19
#           18       1.00      1.00      1.00        19
#           19       0.95      1.00      0.97        19
#           20       1.00      0.95      0.97        19
#           21       1.00      0.83      0.91        12
#           22       0.83      1.00      0.90        19
#           23       0.83      1.00      0.90        19
#           24       0.42      0.58      0.49        19
#           25       1.00      0.95      0.97        19
#           26       1.00      0.88      0.93        16
#           27       1.00      0.95      0.97        19
#           28       0.83      1.00      0.90        19
#           29       0.91      0.83      0.87        12
#           30       0.85      0.89      0.87        19
#           31       0.00      0.00      0.00         3
#           32       0.80      0.86      0.83        14
#           33       0.86      0.67      0.75         9
#           34       0.75      0.86      0.80         7
#           35       0.86      1.00      0.93        19
#           36       0.74      0.89      0.81        19
#           37       0.94      0.79      0.86        19
#           38       0.88      0.78      0.82        18
#           39       0.77      0.89      0.83        19
#           40       0.80      0.57      0.67         7
#           41       0.89      0.89      0.89        19
#           42       0.83      0.79      0.81        19
#           43       0.89      0.84      0.86        19
#           44       0.67      0.63      0.65        19
#           45       0.95      0.95      0.95        19
#           46       0.89      0.89      0.89        19
#           47       0.95      0.95      0.95        19
#           48       0.90      0.95      0.92        19
#           49       0.82      0.74      0.78        19
#           50       0.79      0.79      0.79        14
#           51       1.00      0.89      0.94        19
#           52       0.75      0.79      0.77        19
#           53       0.68      1.00      0.81        19
#           54       0.89      0.80      0.84        10
#           55       0.94      0.84      0.89        19
#           56       0.85      0.94      0.89        18
#           57       0.94      0.84      0.89        19
#           58       0.90      0.95      0.92        19
#           59       0.88      0.79      0.83        19
#           60       1.00      0.94      0.97        18
#           61       0.90      1.00      0.95        19
#           62       0.94      0.89      0.92        19
#           63       0.86      1.00      0.93        19
#
#     accuracy                           0.86      1076
#    macro avg       0.85      0.83      0.84      1076
# weighted avg       0.86      0.86      0.86      1076
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### Word2Vec + Dense Layer

# %%
sentences = [text.split() for text in train['text']]
w2v_model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)

# %%
def sentence_to_avg_vector(text, model):
    words = text.split()
    vectors = []

    for w in words:
        if w in model.wv:
            vectors.append(model.wv[w])

    if len(vectors) == 0:
        return np.zeros(model.vector_size)

    return np.mean(vectors, axis=0)

# %%
def convert_df_to_vectors(df, text_column, model):
    X = np.array([sentence_to_avg_vector(text, model)
                  for text in df[text_column]])
    return X

# %%
X_train_avg = convert_df_to_vectors(train, "text", w2v_model)
X_val_avg   = convert_df_to_vectors(val, "text", w2v_model)

# %%
model = Sequential([
    Input((w2v_model.vector_size,)),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(X_train_avg, train_labels, epochs=20, batch_size=32, validation_data=(X_val_avg, val_labels))
# Out:
# Epoch 1/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0218 - loss: 4.1468 - val_accuracy: 0.0530 - val_loss: 4.0165
# Epoch 2/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0582 - loss: 3.8900 - val_accuracy: 0.0883 - val_loss: 3.5793
# Epoch 3/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1012 - loss: 3.5280 - val_accuracy: 0.1059 - val_loss: 3.4674
# Epoch 4/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1228 - loss: 3.3686 - val_accuracy: 0.1375 - val_loss: 3.3846
# Epoch 5/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1436 - loss: 3.2780 - val_accuracy: 0.1468 - val_loss: 3.2138
# Epoch 6/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1559 - loss: 3.1793 - val_accuracy: 0.1812 - val_loss: 3.1184
# Epoch 7/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1821 - loss: 3.0594 - val_accuracy: 0.2026 - val_loss: 3.0308
# Epoch 8/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1919 - loss: 2.9868 - val_accuracy: 0.1952 - val_loss: 3.0554
# Epoch 9/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2070 - loss: 2.9421 - val_accuracy: 0.1840 - val_loss: 3.0074
# Epoch 10/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2225 - loss: 2.8817 - val_accuracy: 0.2240 - val_loss: 2.8781
# Epoch 11/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2246 - loss: 2.8185 - val_accuracy: 0.2379 - val_loss: 2.8187
# Epoch 12/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2431 - loss: 2.7690 - val_accuracy: 0.2556 - val_loss: 2.7976
# Epoch 13/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2461 - loss: 2.7440 - val_accuracy: 0.2704 - val_loss: 2.7494
# Epoch 14/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2734 - loss: 2.6803 - val_accuracy: 0.2528 - val_loss: 2.7807
# Epoch 15/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2696 - loss: 2.6571 - val_accuracy: 0.2853 - val_loss: 2.6690
# Epoch 16/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2735 - loss: 2.6020 - val_accuracy: 0.2770 - val_loss: 2.6605
# Epoch 17/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2826 - loss: 2.5785 - val_accuracy: 0.2816 - val_loss: 2.6472
# Epoch 18/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3082 - loss: 2.5128 - val_accuracy: 0.2760 - val_loss: 2.6440
# Epoch 19/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3222 - loss: 2.4915 - val_accuracy: 0.2807 - val_loss: 2.6381
# Epoch 20/20
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3184 - loss: 2.4880 - val_accuracy: 0.3169 - val_loss: 2.5488

# %%
y_pred = np.argmax(model.predict(X_val_avg), axis=1)
print(classification_report(val_labels, y_pred))
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.29      0.63      0.40        19
#            1       0.62      0.45      0.53        11
#            2       0.48      0.84      0.62        19
#            3       0.29      0.25      0.27         8
#            4       0.12      0.07      0.09        15
#            5       0.14      0.08      0.10        13
#            6       0.00      0.00      0.00        19
#            7       0.34      0.58      0.43        19
#            8       0.25      0.21      0.23        19
#            9       0.00      0.00      0.00        19
#           10       0.00      0.00      0.00         8
#           11       0.18      0.58      0.28        19
#           12       0.40      0.25      0.31         8
#           13       0.07      0.05      0.06        19
#           14       0.12      0.05      0.07        19
#           15       0.38      0.16      0.22        19
#           16       0.38      0.32      0.34        19
#           17       0.77      0.53      0.62        19
#           18       0.51      0.95      0.67        19
#           19       0.20      0.53      0.29        19
#           20       0.31      0.58      0.40        19
#           21       0.38      0.42      0.40        12
#           22       0.50      0.42      0.46        19
#           23       0.46      0.58      0.51        19
#           24       0.00      0.00      0.00        19
#           25       0.71      0.26      0.38        19
#           26       0.67      0.50      0.57        16
#           27       0.67      0.32      0.43        19
#           28       0.53      0.47      0.50        19
#           29       1.00      0.25      0.40        12
#           30       0.68      0.89      0.77        19
#           31       0.00      0.00      0.00         3
#           32       0.37      0.71      0.49        14
#           33       0.43      0.67      0.52         9
#           34       0.50      0.14      0.22         7
#           35       0.53      0.47      0.50        19
#           36       0.32      0.42      0.36        19
#           37       0.46      0.32      0.38        19
#           38       0.32      0.44      0.37        18
#           39       0.36      0.47      0.41        19
#           40       0.00      0.00      0.00         7
#           41       0.30      0.16      0.21        19
#           42       0.33      0.05      0.09        19
#           43       0.20      0.11      0.14        19
#           44       0.18      0.11      0.13        19
#           45       0.46      0.58      0.51        19
#           46       0.19      0.26      0.22        19
#           47       0.67      0.11      0.18        19
#           48       0.50      0.05      0.10        19
#           49       0.17      0.32      0.22        19
#           50       0.41      0.50      0.45        14
#           51       0.15      0.11      0.12        19
#           52       0.18      0.32      0.23        19
#           53       0.00      0.00      0.00        19
#           54       0.00      0.00      0.00        10
#           55       0.20      0.16      0.18        19
#           56       0.00      0.00      0.00        18
#           57       0.47      0.42      0.44        19
#           58       0.10      0.16      0.12        19
#           59       0.08      0.05      0.06        19
#           60       0.29      0.44      0.35        18
#           61       0.43      0.53      0.48        19
#           62       0.14      0.11      0.12        19
#           63       0.14      0.21      0.17        19
#
#     accuracy                           0.32      1076
#    macro avg       0.32      0.31      0.28      1076
# weighted avg       0.32      0.32      0.29      1076
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
y_pred.shape
# Out:
# (1076, 64)

# %% [markdown]
# ## Week 3

# %% [markdown]
# Document Vecterization: transform a text/doc into a vector
# - use count/binary vector

# %% [markdown]
# Big Data technologies
# - parallel processing
# - distributed processing

# %% [markdown]
# Apache Spark
# - PySpark

# %% [markdown]
# ## Week 5

# %% [markdown]
# Dense Vector: 50-100 dimensions
# - Word2Vec: CBOW, Skip-gram
# - GloVe
# - fastText
# - Transformer-based models (BERT)

# %% [markdown]
# Machine Learning
# - Input: documents
# - Output: wword vector

# %% [markdown]
# Idea:
# - CBOW: p(w|context)
# - Skip-gram: p(context|w)
